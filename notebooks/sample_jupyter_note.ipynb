# %% [markdown]
# # Sample note book
#
# ## Install and run jupyter note book in python virtual environment
#
#
#    ### Active virtual environment
# `source .ven/bin/activate`
#    >after activate virtual environment, the command line starts with `(.venv)`
#
#    ### pip3 install classic jupyternote book
# `pip3 install notebook`
#
#    ### start the note book server
# `
# juypter notebook
# `

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.linspace(0,3*np.pi,500)
plt.plot(x, np.sin(x**2))
plt.title('A Simple chirp');
